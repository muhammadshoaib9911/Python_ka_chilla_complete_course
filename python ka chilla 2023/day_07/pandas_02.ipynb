# %% [markdown]
# # How to import Dataset in python using Pandas
# Written by: Muhammad Shoaib\
# Date: 3.12.2025\
# Email: shoaibxdev9@gmail.com

# %%
import pandas as pd

# %%
df = pd.read_excel("pandas_01_day6.xlsx")

# %%
df
# Out:
#    Height  Weight Favourite Dish
# 0       6      50        Biryani
# 1     6'1      78        Biryani
# 2     6'0     125    Chapel Kaba
# 3    5’11      72  Karahi Ghosht
# 4     5.6      86  Chicken Pulao
# ..    ...     ...            ...
# 82    5.1      96        Biryani
# 83      5      57        Biryani
# 84      5      25        Biryani
# 85      5      31        Biryani
# 86      5      50  Chicken Pulao
#
# [87 rows x 3 columns]

# %% [markdown]
# ## View Data frame in python using Pandas

# %%
df.head()
# Out:
#   Height  Weight Favourite Dish
# 0      6      50        Biryani
# 1    6'1      78        Biryani
# 2    6'0     125    Chapel Kaba
# 3   5’11      72  Karahi Ghosht
# 4    5.6      86  Chicken Pulao

# %%
df.tail()
# Out:
#    Height  Weight Favourite Dish
# 82    5.1      96        Biryani
# 83      5      57        Biryani
# 84      5      25        Biryani
# 85      5      31        Biryani
# 86      5      50  Chicken Pulao

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     object
#  1   Weight          87 non-null     int64
#  2   Favourite Dish  87 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %%
df.shape
# Out:
# (87, 3)

# %%
df.describe()
# Out:
#            Weight
# count   87.000000
# mean    70.459770
# std     16.753899
# min     25.000000
# 25%     60.000000
# 50%     70.000000
# 75%     80.000000
# max    125.000000

# %%
df.T
# Out:
#                      0        1            2              3              4   \
# Height                6      6'1          6'0           5’11            5.6
# Weight               50       78          125             72             86
# Favourite Dish  Biryani  Biryani  Chapel Kaba  Karahi Ghosht  Chicken Pulao
#
#                    5        6        7        8      9   ...             77  \
# Height            5.3      5.8      5.8      5.7  5'8''  ...            5.1
# Weight             75       65       72       75     52  ...             62
# Favourite Dish  Pasta  Biryani  Biryani  Biryani  Pasta  ...  Karahi Ghosht
#
#                          78           79       80       81       82       83  \
# Height                  5.1          5.1      5.1      5.1      5.1        5
# Weight                  103           61       85       70       96       57
# Favourite Dish  Chapel Kaba  Chapel Kaba  Biryani  Biryani  Biryani  Biryani
#
#                      84       85             86
# Height                5        5              5
# Weight               25       31             50
# Favourite Dish  Biryani  Biryani  Chicken Pulao
#
# [3 rows x 87 columns]

# %%
import matplotlib.pyplot as plt 
countries = ["Pakistan", "India", "China", "Iran"] 
population = [230, 1400, 1440, 85] 
plt.barh(countries, population) 
# barh = horizontal bar chart 
plt.title("Country Populations") 
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [5, 7, 8, 9, 4] 
y = [10, 12, 15, 20, 5] 
plt.scatter(x, y)  # Draws individual points 
plt.title("Scatter Plot Example") 
plt.xlabel("X Values") 
plt.ylabel("Y Values") 
plt.show()

# %%
#Program 6: Histogram 
import matplotlib.pyplot as plt 
ages = [18, 22, 25, 30, 35, 40, 22, 25, 30, 35, 40] 
plt.hist(ages, bins=5) 
# bins = number of groups 
plt.title("Age Distribution") 
plt.xlabel("Ages") 
plt.ylabel("Frequency") 
plt.show()
