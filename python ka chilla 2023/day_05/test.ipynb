# %% [markdown]
# ## Subject of this notebook:
# Authored by: Muhammad Shoaib
# Where to contact:

# %% [markdown]
# This is used for simple print

# %%
# code1 
print ("Shoaib")
# Out:
# Shoaib

# %% [markdown]
# this is used for getting input from the user

# %%
# code2
name = input("Enter your name: ")

# %% [markdown]
# this is used for print the input name

# %%
# code3
print("Hello", name)
# Out:
# Hello
